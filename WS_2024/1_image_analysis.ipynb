# %% [markdown]
# <a href="https://colab.research.google.com/github/iimog/master-bioinf-lecture/blob/main/WS_2024/1_image_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 + 1
# Out:
# 2

# %%
import skimage as ski

# %%
img = ski.io.imread("https://figshare.com/ndownloader/files/34498448")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (303, 306, 3)

# %%
img[0,0]
# Out:
# array([255, 255, 255], dtype=uint8)

# %% [markdown]
# ## Convert to gray

# %%
gray_img = ski.color.rgb2gray(img)

# %%
gray_img.shape
# Out:
# (303, 306)

# %%
plt.imshow(gray_img, cmap="gray")
plt.colorbar()

# %%
gray_img.flatten().shape
# Out:
# (92718,)

# %%
plt.hist(gray_img.flatten(), bins=256, range=(0,1));

# %% [markdown]
# ## Blurring

# %%
blurred_img = ski.filters.gaussian(gray_img, sigma=1)

# %%
plt.imshow(blurred_img, cmap="gray")

# %% [markdown]
# ## Create binary mask

# %%
mask = blurred_img < 0.2

# %%
mask
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
plt.imshow(mask, cmap="gray")

# %% [markdown]
# ## Connected components

# %%
labeled_img, count = ski.measure.label(mask, return_num=True)

# %%
count
# Out:
# 11

# %% [markdown]
# ## Try on second image

# %%
img2 = ski.io.imread("https://figshare.com/ndownloader/files/34498442")
plt.imshow(img2)

# %%
gray_img2 = ski.color.rgb2gray(img2)
blurred_img2 = ski.filters.gaussian(gray_img2, sigma=1)
mask2 = blurred_img2 < 0.2
_, count = ski.measure.label(mask2, return_num=True)
count
# Out:
# 74
